# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import matplotlib.pyplot as plt

# %%
t = np.arange(0, 2000)
X = np.sin(0.01 * t)

# %%
plt.plot(X)

# %%
X[:10]
# Out:
# array([0.        , 0.00999983, 0.01999867, 0.0299955 , 0.03998933,
#        0.04997917, 0.05996401, 0.06994285, 0.07991469, 0.08987855])

# %%
# [
#     [0.        , 0.00999983, 0.01999867] -> [0.0299955],
#     [0.00999983, 0.01999867, 0.0299955] -> [0.03998933],
#     [0.01999867, 0.0299955 , 0.03998933] -> [0.04997917]
#     ...
# ]

# %%
X_train, X_test = X[:1500], X[1500:]

# %%
model = Sequential()
model.add(SimpleRNN(units=64, activation='tanh'))
model.add(Dense(1))

# %%
model.compile(loss='mean_absolute_error', optimizer='adam')

# %%
XT, yT = [], []
for i in range(len(X_train) - 15):
    d = i + 15
    XT.append(X_train[i:d,])
    yT.append(X_train[d])

# %%
Xt, yt = [], []
for i in range(len(X_test) - 15):
    d = i + 15
    Xt.append(X_test[i:d,])
    yt.append(X_test[d])

# %%
XT = np.array(XT)
Xt = np.array(Xt)

# %%
XT.shape
# Out:
# (1485, 15)

# %%
XT[2]
# Out:
# array([0.01999867, 0.0299955 , 0.03998933, 0.04997917, 0.05996401,
#        0.06994285, 0.07991469, 0.08987855, 0.09983342, 0.1097783 ,
#        0.11971221, 0.12963414, 0.13954311, 0.14943813, 0.15931821])

# %%
yT[2]
# Out:
# np.float64(0.16918234906699603)

# %%
XT = np.reshape(XT, (XT.shape[0], XT.shape[1], 1))
Xt = np.reshape(Xt, (Xt.shape[0], Xt.shape[1], 1))

# %%
XT.shape
# Out:
# (1485, 15, 1)

# %%
XT[0]
# Out:
# array([[0.        ],
#        [0.00999983],
#        [0.01999867],
#        [0.0299955 ],
#        [0.03998933],
#        [0.04997917],
#        [0.05996401],
#        [0.06994285],
#        [0.07991469],
#        [0.08987855],
#        [0.09983342],
#        [0.1097783 ],
#        [0.11971221],
#        [0.12963414],
#        [0.13954311]])

# %%
yT = np.array(yT)
yt = np.array(yt)

# %%
model.fit(XT, yT, epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0813
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0130
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0098
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024

# %%
model.evaluate(Xt, yt)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# 0.001009156578220427

# %%
XTPredicted = model.predict(XT)
XtPredicted = model.predict(Xt)
XFinal = np.concatenate([XTPredicted, XtPredicted], axis=0)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
plt.plot(X, color='red')
plt.plot(XFinal, color='blue')
